# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import RMSprop
import numpy as np
import tensorflow as tf
gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess=tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

x_data = np.array([[73., 80., 75.],
                   [93., 88., 93.],
                   [89., 91., 90.],
                   [96., 98., 100.],
                   [73., 66., 70.]])
y_data = np.array([[152.],
                   [185.],
                   [180.],
                   [196.],
                   [142.]])

model = Sequential()
model.add(Dense(1, input_dim=3))

rmsprop = RMSprop(lr=1e-2)
model.compile(loss='mse', optimizer=rmsprop)
model.fit(x_data, y_data, epochs=1000)

y_predict = model.predict(np.array([[95., 100., 80]]))
print(y_predict)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 0s 83ms/sample - loss: 50222.8281
# Epoch 2/1000
# 5/5 [==============================] - 0s 399us/sample - loss: 46634.8438
# Epoch 3/1000
# 5/5 [==============================] - 0s 399us/sample - loss: 44159.2383
# Epoch 4/1000
# 5/5 [==============================] - 0s 598us/sample - loss: 42160.3477
# Epoch 5/1000
# 5/5 [==============================] - 0s 599us/sample - loss: 40439.3867
# Epoch 6/1000
# 5/5 [==============================] - 0s 598us/sample - loss: 38904.8086
# Epoch 7/1000
# 5/5 [==============================] - 0s 398us/sample - loss: 37505.8828
# Epoch 8/1000
# 5/5 [==============================] - 0s 387us/sample - loss: 36211.1641
# Epoch 9/1000
# 5/5 [==============================] - 0s 399us/sample - loss: 34999.6914
# Epoch 10/1000
# 5/5 [==============================] - 0s 591us/sample - loss: 33856.6992
# Epoch 11/1000
# ...

# %% [markdown]
# # p879 로지스틱 회귀

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import RMSprop
import numpy as np
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import tensorflow as tf


sess = tf.Session(config=tf.ConfigProto(
gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction = 0.4), log_device_placement=True))

x_train = np.array([2,4,5,7,8,10,25])
y_train = np.array([0,0,0,1,1,1,1])

model = Sequential()
model.add(Dense(1,input_dim=1,activation="sigmoid"))                  #시그모이드 

                         #SGD : 경사 하강법 중 하나 , Ir= 학습률
# prints summary of the model to the terminal

          
model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=['accuracy'])                                 #compile :학습 모델 지정  , loss= 오차 
                                                                     #binary_crossentropy = 2인 분류

model.summary()

model.fit(x_train, y_train, epochs=200)                 # 학습실행 데이터 , 정답, 실행수


          

y_predict = model.predict(np.array([5]))
print(y_predict)
          

d_predict=model.predict_classes(np.array([5]))          
print(d_predict)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7/7 [==============================] - 0s 26ms/sample - loss: 8.1905 - acc: 0.4286
# Epoch 2/200
# 7/7 [==============================] - 0s 290us/sample - loss: 8.1846 - acc: 0.4286
# Epoch 3/200
# 7/7 [==============================] - 0s 426us/sample - loss: 8.1800 - acc: 0.4286
# Epoch 4/200
# 7/7 [==============================] - 0s 429us/sample - loss: 8.1797 - acc: 0.4286
# Epoch 5/200
# 7/7 [==============================] - 0s 570us/sample - loss: 8.1779 - acc: 0.4286
# Epoch 6/200
# 7/7 [==============================] - 0s 428us/sample - loss: 8.1742 - acc: 0.4286
# Epoch 7/200
# ...
