# %%
from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

x=np.arange(1,11)
y=x*5+np.random.randn(10)*5

#한글지원
font_fname = "c:/Windows/Fonts/malgun.TTF"
font_family =font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"]=font_family

plt.plot(x,y,"gp--")  #산점도   , 색,포인트,선모양
plt.title("산점도 제목",fontdict={'fontsize':25,'fontweight':"bold"},loc="left")

plt.xlabel("x-축",labelpad=15)
plt.ylabel("y-축",fontdict={'fontsize':10,'fontweight':"bold"})

plt.show()

# %%
#p342

from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager



x=np.arange(1,11)
y1=x*5+np.random.randn(10)*5
y2=5+x+5+np.random.randn(10)*5

plt.plot(x,y1,"p")
plt.plot(x,y2,"rp")
plt.title("x-y1, x-y2 산점도")
plt.xlabel("x-축")
plt.ylabel("y-축")
plt.legend(["남자","여자"],loc='lower right')
plt.axis(xmin=0,xmax=15,ymin=0,ymax=100)
plt.minorticks_on()
plt.grid(b=True,which='major',axis='y')
plt.show()

# %%
#p 344 막대그래프 그리기

from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

#한글지원
font_fname = "c:/Windows/Fonts/malgun.TTF"
font_family =font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"]=font_family

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"])
print(AreaTbl)

plt.bar(AreaTbl.index,AreaTbl,bottom=10,color="gray", edgecolor="blue")
plt.show()
# Out:
# 동북권    140
# 동남권     92
# 서북권     81
# 서남권     76
# 도심권     11
# Name: Area, dtype: int64

# %%
#p 345 원그래프 그리기

from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"])

print(AreaTbl)
plt.pie(AreaTbl, explode=(0,2,0,0,0),labels=AreaTbl.index,colors=["r","y","g","c","m"],autopct="%5.1f%%", shadow=True)
plt.show()
# Out:
# 동북권    140
# 동남권     92
# 서북권     81
# 서남권     76
# 도심권     11
# Name: Area, dtype: int64

# %%
plt.boxplot(df.Price,notch=True,vert=False,meanline=True ,whis=3,showmeans=True,labels=["임대가"])
plt.show()

# %%
#p347 상자 도표



from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"])

plt.boxplot([df.FAR,df.Price],notch=True,vert=False,whis=3,labels=["용적률","임대가"])
plt.show()

# %%
#p348
from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
#한글지원
font_fname = "c:/Windows/Fonts/malgun.TTF"
font_family =font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"]=font_family

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"])

plt.hist(df.Price,bins=8,color="y",density=True)
plt.show()

# %%
plt.plot(df.FAR,df.Price,color='green',marker='o',linestyle='dashed')
plt.show()

# %%
#p350 산점도

plt.plot(df.FAR,"b*")
plt.plot(df.Price,"go")
plt.legend(["용적률","임대가"],loc='upper right')
plt.show()

# %%
#p348 분할 영역 그래프 4면
from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
#한글지원
font_fname = "c:/Windows/Fonts/malgun.TTF"
font_family =font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"]=font_family

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"])

plt.figure(figsize=(7,5))
plt.subplot(221)
plt.hist(df.FAR,bins=10)

plt.subplot(224)
plt.hist(df.Price,bins=10)

plt.subplot(222,frameon=False)
plt.boxplot(df.FAR,vert=False,labels=["용적률"])

plt.subplot(223,frameon=False)
plt.boxplot(df.Price,vert=False,labels=["임대가"])

plt.show()

# %%
#p350 분할 영역 그래프 3면

plt.figure(figsize=(7,5))
plt.subplot(223)
plt.hist(df.FAR,bins=10)

plt.subplot(224)
plt.hist(df.Price,bins=10)

plt.subplot(211)
plt.plot(df.FAR, df.Price, "ko")

plt.show()

# %%
#p353 pandas 그래프

df.plot()

# %%
#354

#p348 분할 영역 그래프 4면
from pandas import Series,DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"]) # = AreaTbl=pd.value_counts(df.Area) 
AreaTbl.plot.bar()
plt.title("지역 현황")
plt.xlabel("지역")
# Out:
# Text(0.5, 0, '지역')

# %%
#p354 누적막대 그래프

crtab=pd.crosstab(df.Area,df.Option)



crtab.plot(kind="barh",stacked=False)

# %%
#p356 원그래프

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/aptdata.csv",header=0,skiprows=7,index_col=None,encoding="utf-8")

AreaTbl=pd.value_counts(df["Area"]) # = AreaTbl=pd.value_counts(df.Area)

AreaTbl.plot(kind="pie", explode=(0,0.2,0,0,0.5),colors=["r","c","y","m","g"],autopct="%5.1f%%",shadow= True)

# %%
#p357  상자그래프

df[["FAR","Price"]].plot(kind="box",vert=False)

# %%
df["Price"].plot(kind="hist",bins=12, color="gray")

# %%
#p358 히스토그램 불투명

df[["FAR","Price"]].plot(kind="hist",color=["gray","darkblue"],density=True,alpha=0.7)

# %%
# p358 pandas 산점도 그래프

df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/pilot.csv", header=0, skiprows=8, index_col=None,encoding="utf-8")

df=df.replace({"G":{1:"엔지니어 수습생" , 2:"파일럿"}})
df.head(5)

df.plot(kind="scatter",x="X1", y="X2", color="purple",marker="D")

# %%
df.plot(kind="scatter",x="X1", y="X2", c="X3", marker='s',alpha=0.7)

# %%
#p360 pandas 영역그래 프
df=pd.read_csv("C:/Users/Affinity/Desktop/lecture/Python_Data/ch02_data/pilot.csv", header=0, skiprows=8, index_col=None,encoding="utf-8")

df=df.replace({"G":{1:"엔지니어 수습생" , 2:"파일럿"}})
df.plot(kind="area")
