# %%
# import sys
# mod = sys.modules[__name__]

# for i in range(15):
# #     setattr(mod, 'test{}'.format(i), i)
#     print(getattr(mod, 'count{}'.format(i+1)))

# %%
import sys
mod = sys.modules[__name__]
import math
from keras import layers
from keras import models
import tensorflow as tf
import numpy as np
from keras import layers
from keras import models
import os, shutil

np.random.seed(3)

sess = tf.Session(config=tf.ConfigProto(
gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction = 0.4), log_device_placement=True))


# 원본 데이터셋을 압축 해제한 디렉터리 경로
original_dataset_dir = 'C:/Users/Affinity/Desktop/project/images/images'

# 소규모 데이터셋을 저장할 디렉터리
base_dir =  'C:/Users/Affinity/Desktop/project/classification'
if os.path.exists(base_dir):  # 반복적인 실행을 위해 디렉토리를 삭제합니다.
    shutil.rmtree(base_dir)   # 하위 디렉토리 및 파일 전체 삭제하기: rmtree()
os.mkdir(base_dir)     

# 훈련, 검증, 테스트 분할을 위한 디렉터리
train_dir = os.path.join(base_dir, 'train')  #os.path.join()  하위 경로 만들기
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# 훈련용 Vincent van Gogh  디렉터리
train_Vincent_van_Gogh_dir = os.path.join(train_dir, 'Vincent van Gogh')
os.mkdir(train_Vincent_van_Gogh_dir)

# 훈련용 Edgar Degas 디렉터리
train_Edgar_Degas_dir = os.path.join(train_dir, 'Edgar Degas')
os.mkdir(train_Edgar_Degas_dir)

# 훈련용 Pablo Picasso 디렉터리
train_Pablo_Picasso_dir = os.path.join(train_dir, 'Pablo Picasso')
os.mkdir(train_Pablo_Picasso_dir)

# 훈련용 Pierre-Auguste Renoir 디렉터리
train_Pierre_Auguste_Renoir_dir = os.path.join(train_dir, 'Pierre_Auguste Renoir')
os.mkdir(train_Pierre_Auguste_Renoir_dir)

# 훈련용 Albrecht_Du_rer 디렉터리
train_Albrecht_Du_rer_dir = os.path.join(train_dir, 'Albrecht_Du_rer')
os.mkdir(train_Albrecht_Du_rer_dir)

# 훈련용 Paul Gauguin 디렉터리
train_Paul_Gauguin_dir = os.path.join(train_dir, 'Paul Gauguin')
os.mkdir(train_Paul_Gauguin_dir)

# 훈련용 Francisco_Goya 디렉터리
train_Francisco_Goya_dir = os.path.join(train_dir, 'Francisco_Goya')
os.mkdir(train_Francisco_Goya_dir)

# 훈련용 Rembrandt 디렉터리
train_Rembrandt_dir = os.path.join(train_dir, 'Rembrandt')
os.mkdir(train_Rembrandt_dir)

# 훈련용 Alfred_Sisley 디렉터리
train_Alfred_Sisley_dir = os.path.join(train_dir, 'Alfred_Sisley')
os.mkdir(train_Alfred_Sisley_dir)

# 훈련용 Titian 디렉터리
train_Titian_dir = os.path.join(train_dir, 'Titian')
os.mkdir(train_Titian_dir)

# 훈련용 Marc_Chagall 디렉터리
train_Marc_Chagall_dir = os.path.join(train_dir, 'Marc_Chagall')
os.mkdir(train_Marc_Chagall_dir)

# 훈련용 Rene_Magritte 디렉터리
train_Rene_Magritte_dir = os.path.join(train_dir, 'Rene_Magritte')
os.mkdir(train_Rene_Magritte_dir)

# 훈련용 Amedeo_Modigliani 디렉터리
train_Amedeo_Modigliani_dir = os.path.join(train_dir, 'Amedeo_Modigliani')
os.mkdir(train_Amedeo_Modigliani_dir)

# 훈련용 Paul_Klee 디렉터리
train_Paul_Klee_dir = os.path.join(train_dir, 'Paul_Klee')
os.mkdir(train_Paul_Klee_dir)

# 훈련용 Henri_Matisse 디렉터리
train_Henri_Matisse_dir = os.path.join(train_dir, 'Henri_Matisse')
os.mkdir(train_Henri_Matisse_dir)



#-----------------------------------------------------------


# 검증용 Vincent van Gogh  디렉터리
validation_Vincent_van_Gogh_dir = os.path.join(validation_dir, 'Vincent van Gogh')
os.mkdir(validation_Vincent_van_Gogh_dir)

# 검증용 Edgar Degas 디렉터리
validation_Edgar_Degas_dir = os.path.join(validation_dir, 'Edgar Degas')
os.mkdir(validation_Edgar_Degas_dir)

# 검증용 Pablo Picasso 디렉터리
validation_Pablo_Picasso_dir = os.path.join(validation_dir, 'Pablo Picasso')
os.mkdir(validation_Pablo_Picasso_dir)

# 검증용 Pierre-Auguste Renoir 디렉터리
validation_Pierre_Auguste_Renoir_dir = os.path.join(validation_dir, 'Pierre_Auguste Renoir')
os.mkdir(validation_Pierre_Auguste_Renoir_dir)

# 검증용 Albrecht_Du_rer 디렉터리
validation_Albrecht_Du_rer_dir = os.path.join(validation_dir, 'Albrecht_Du_rer')
os.mkdir(validation_Albrecht_Du_rer_dir)

# 검증용 Paul Gauguin 디렉터리
validation_Paul_Gauguin_dir = os.path.join(validation_dir, 'Paul Gauguin')
os.mkdir(validation_Paul_Gauguin_dir)

# 검증용 Francisco_Goya 디렉터리
validation_Francisco_Goya_dir = os.path.join(validation_dir, 'Francisco_Goya')
os.mkdir(validation_Francisco_Goya_dir)

# 검증용 Rembrandt 디렉터리
validation_Rembrandt_dir = os.path.join(validation_dir, 'Rembrandt')
os.mkdir(validation_Rembrandt_dir)

# 검증용 Alfred_Sisley 디렉터리
validation_Alfred_Sisley_dir = os.path.join(validation_dir, 'Alfred_Sisley')
os.mkdir(validation_Alfred_Sisley_dir)

# 검증용 Titian 디렉터리
validation_Titian_dir = os.path.join(validation_dir, 'Titian')
os.mkdir(validation_Titian_dir)

# 검증용 Marc_Chagall 디렉터리
validation_Marc_Chagall_dir = os.path.join(validation_dir, 'Marc_Chagall')
os.mkdir(validation_Marc_Chagall_dir)

# 검증용 Rene_Magritte 디렉터리
validation_Rene_Magritte_dir = os.path.join(validation_dir, 'Rene_Magritte')
os.mkdir(validation_Rene_Magritte_dir)

# 검증용 Amedeo_Modigliani 디렉터리
validation_Amedeo_Modigliani_dir = os.path.join(validation_dir, 'Amedeo_Modigliani')
os.mkdir(validation_Amedeo_Modigliani_dir)

# 검증용 Paul_Klee 디렉터리
validation_Paul_Klee_dir = os.path.join(validation_dir, 'Paul_Klee')
os.mkdir(validation_Paul_Klee_dir)

# 검증용 Henri_Matisse 디렉터리
validation_Henri_Matisse_dir = os.path.join(validation_dir, 'Henri_Matisse')
os.mkdir(validation_Henri_Matisse_dir)
#---------------------------------------------------------------------------------------------

# 테스트용 Vincent van Gogh  디렉터리
test_Vincent_van_Gogh_dir = os.path.join(test_dir, 'Vincent van Gogh')
os.mkdir(test_Vincent_van_Gogh_dir)

# 테스트용 Edgar Degas 디렉터리
test_Edgar_Degas_dir = os.path.join(test_dir, 'Edgar Degas')
os.mkdir(test_Edgar_Degas_dir)

# 테스트용 Pablo Picasso 디렉터리
test_Pablo_Picasso_dir = os.path.join(test_dir, 'Pablo Picasso')
os.mkdir(test_Pablo_Picasso_dir)

# 테스트용 Pierre-Auguste Renoir 디렉터리
test_Pierre_Auguste_Renoir_dir = os.path.join(test_dir, 'Pierre_Auguste Renoir')
os.mkdir(test_Pierre_Auguste_Renoir_dir)

# 테스트용 Albrecht_Du_rer 디렉터리
test_Albrecht_Du_rer_dir = os.path.join(test_dir, 'Albrecht_Du_rer')
os.mkdir(test_Albrecht_Du_rer_dir)

# 테스트용 Paul Gauguin 디렉터리
test_Paul_Gauguin_dir = os.path.join(test_dir, 'Paul Gauguin')
os.mkdir(test_Paul_Gauguin_dir)

# 테스트용 Francisco_Goya 디렉터리
test_Francisco_Goya_dir = os.path.join(test_dir, 'Francisco_Goya')
os.mkdir(test_Francisco_Goya_dir)

# 테스트용 Rembrandt 디렉터리
test_Rembrandt_dir = os.path.join(test_dir, 'Rembrandt')
os.mkdir(test_Rembrandt_dir)

# 테스트용 Alfred_Sisley 디렉터리
test_Alfred_Sisley_dir = os.path.join(test_dir, 'Alfred_Sisley')
os.mkdir(test_Alfred_Sisley_dir)

# 테스트용 Titian 디렉터리
test_Titian_dir = os.path.join(test_dir, 'Titian')
os.mkdir(test_Titian_dir)

# 테스트용 Marc_Chagall 디렉터리
test_Marc_Chagall_dir = os.path.join(test_dir, 'Marc_Chagall')
os.mkdir(test_Marc_Chagall_dir)

# 테스트용 Rene_Magritte 디렉터리
test_Rene_Magritte_dir = os.path.join(test_dir, 'Rene_Magritte')
os.mkdir(test_Rene_Magritte_dir)

# 테스트용 Amedeo_Modigliani 디렉터리
test_Amedeo_Modigliani_dir = os.path.join(test_dir, 'Amedeo_Modigliani')
os.mkdir(test_Amedeo_Modigliani_dir)

# 테스트용 Paul_Klee 디렉터리
test_Paul_Klee_dir = os.path.join(test_dir, 'Paul_Klee')
os.mkdir(test_Paul_Klee_dir)

# 테스트용 Henri_Matisse 디렉터리
test_Henri_Matisse_dir = os.path.join(test_dir, 'Henri_Matisse')
os.mkdir(test_Henri_Matisse_dir)

path1= "C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh"     
count1=len(os.listdir(path1))                                
count51=math.ceil(count1*0.5)                                # 각 데이터의 50퍼센트 계산(훈련 셋)                                  
count81=math.ceil(count1*0.8)       # 각 데이터의 80퍼센트 계산(테스트 셋)

path2= "C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas"     
count2=len(os.listdir(path2))
count52=math.ceil(count2*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count82=math.ceil(count2*0.8)       # 각 데이터의 80퍼센트 계산


path3= "C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso"     
count3=len(os.listdir(path3))
count53=math.ceil(count3*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count83=math.ceil(count3*0.8)          # 각 데이터의 80퍼센트 계산


path4="C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir"     
count4=len(os.listdir(path4))
count54=math.ceil(count4*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count84=math.ceil(count4*0.8)      # 각 데이터의 80퍼센트 계산

path5= "C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer"     
count5=len(os.listdir(path5))
count55=math.ceil(count5*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count85=math.ceil(count5*0.8)      # 각 데이터의 80퍼센트 계산

path6= "C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin"     
count6=len(os.listdir(path6))  
count56=math.ceil(count6*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count86=math.ceil(count6*0.8)       # 각 데이터의 80퍼센트 계산
   
path7= "C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya"     
count7=len(os.listdir(path7))
count57=math.ceil(count7*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count87=math.ceil(count7*0.8)        # 각 데이터의 80퍼센트 계산

path8= "C:/Users/Affinity/Desktop/project/images/images/Rembrandt"     
count8=len(os.listdir(path8))
count58=math.ceil(count8*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count88=math.ceil(count8*0.8)      # 각 데이터의 80퍼센트 계산


path9= "C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley"     
count9=len(os.listdir(path9))
count59=math.ceil(count9*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count89=math.ceil(count9*0.8)      # 각 데이터의 80퍼센트 계산


path10= "C:/Users/Affinity/Desktop/project/images/images/Titian"     
count10=len(os.listdir(path10))
count10_5=math.ceil(count10*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count10_8=math.ceil(count10*0.8)     # 각 데이터의 80퍼센트 계산


path11= "C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall"     
count11=len(os.listdir(path11))
count11_5=math.ceil(count11*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count11_8=math.ceil(count11*0.8)       # 각 데이터의 80퍼센트 계산


path12= "C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte"     
count12=len(os.listdir(path12))
count12_5=math.ceil(count12*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count12_8=math.ceil(count12*0.8)       # 각 데이터의 80퍼센트 계산


path13= "C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani"     
count13=len(os.listdir(path13))
count13_5=math.ceil(count13*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count13_8=math.ceil(count13*0.8)           # 각 데이터의 80퍼센트 계산

path14= "C:/Users/Affinity/Desktop/project/images/images/Paul_Klee"     
count14=len(os.listdir(path14))
count14_5=math.ceil(count14*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count14_8=math.ceil(count14*0.8)       # 각 데이터의 80퍼센트 계산

path15= "C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse"     
count15=len(os.listdir(path15))
count15_5=math.ceil(count15*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count15_8=math.ceil(count15*0.8)        # 각 데이터의 80퍼센트 계산



#----------------------------------------------------------------------
#처음 n 개의 train_Vincent_van_Gogh그림을 train_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(1,count51)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(train_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)

# 다음 n개 train_Vincent_van_Gogh 그림을 validation_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(count51, count81)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(validation_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)
    
# 다음 n개 train_Vincent_van_Gogh 그림을 test_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(count81, count1)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(test_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)
 
    
#처음 n 개의 Edgar_Degas그림을 train_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(1,count52)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(train_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)

# 다음 n개 Edgar_Degas 그림을 validation_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(count52, count82)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(validation_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)
    
# 다음 n개 Edgar_Degas그림을 test_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(count82, count2)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(test_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(1,count53)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(train_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(count53, count83)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(validation_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(count83, count3)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(test_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)
#-----    
fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(1,count54)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(train_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)


fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(count54, count84)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(validation_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)
    

fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(count84, count4)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(test_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)
    
#------
fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(1,count55)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(train_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(count55, count85)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(validation_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(count85, count5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(test_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)
    
#---------    
fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(1,count56)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(train_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(count56, count86)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(validation_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(count86, count6)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(test_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)
#-------    
fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(1,count57)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(train_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(count57, count87)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(validation_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(count87, count7)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(test_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)
    
    
#----------------    
fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(1,count58)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(train_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(count58, count88)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(validation_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(count88, count8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(test_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)
    
#-------------
fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(1,count59)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(train_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(count59, count89)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(validation_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(count89, count9)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(test_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)
    
#---------------------

fnames = ['Titian_{}.jpg'.format(i) for i in range(1,count10_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(train_Titian_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Titian_{}.jpg'.format(i) for i in range(count10_5, count10_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(validation_Titian_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Titian_{}.jpg'.format(i) for i in range(count10_8, count10)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(test_Titian_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(1,count11_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(train_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(count11_5, count11_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(validation_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(count11_8, count11)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(test_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(1,count12_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(train_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(count12_5, count12_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(validation_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(count12_8, count12)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(test_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)
    
    
#------------
fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(1,count13_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(train_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(count13_5, count13_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(validation_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(count13_8, count13)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(test_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)
    
#------------
fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(1,count14_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(train_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(count14_5, count14_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(validation_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(count14_8, count14)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(test_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(1,count15_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(train_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(count15_5, count15_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(validation_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(count15_8, count15)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(test_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)


    # for i in range(10,16):
#     setattr(mod, 'test{}'.format(i), i)
#     print(getattr(mod, 'count{}_5'.format(i)))
#     print(src)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-02eeebee545f> in <module>
#       2 mod = sys.modules[__name__]
#       3 import math
# ----> 4 from keras import layers
#       5 from keras import models
#       6 import tensorflow as tf
#
# ~\.conda\envs\keras\lib\site-packages\keras\__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~\.conda\envs\keras\lib\site-packages\keras\utils\__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~\.conda\envs\keras\lib\site-packages\keras\utils\conv_utils.py in <module>
#       7 from six.moves import range
# ...

# %%
print('훈련용 Vincent_van_Gogh 전체 개수:', len(os.listdir(train_Vincent_van_Gogh_dir)))
print('검증용 Vincent_van_Gogh 전체 개수:', len(os.listdir(validation_Vincent_van_Gogh_dir)))
print('테스트용 Vincent_van_Gogh 전체 개수:', len(os.listdir(test_Vincent_van_Gogh_dir)))

print('훈련용 Edgar_Degas 전체 개수:', len(os.listdir(train_Edgar_Degas_dir)))
print('검증용 Edgar_Degas 전체 개수:', len(os.listdir(validation_Edgar_Degas_dir)))
print('테스트용 Edgar_Degas 전체 개수:', len(os.listdir(test_Edgar_Degas_dir)))
                    
print('훈련용 Pablo_Picasso 전체 개수:', len(os.listdir(train_Pablo_Picasso_dir)))
print('검증용 Pablo_Picasso 전체 개수:', len(os.listdir(validation_Pablo_Picasso_dir)))
print('테스트용 Pablo_Picasso 전체 개수:', len(os.listdir(test_Pablo_Picasso_dir)))
                                                
print('훈련용 Pierre_Auguste_Renoir 전체 개수:', len(os.listdir(train_Pierre_Auguste_Renoir_dir)))
print('검증용 Pierre_Auguste_Renoir 전체 개수:', len(os.listdir(validation_Pierre_Auguste_Renoir_dir)))
print('테스트용 Pierre_Auguste_Renoir 전체 개수:', len(os.listdir(test_Pierre_Auguste_Renoir_dir)))

# %%
from keras import layers
from keras import models
from keras.models import Sequential
import tensorflow as tf

leaky_relu = tf.nn.leaky_relu

model=Sequential()
model.add(layers.Conv2D(64,(3,3),activation=leaky_relu,input_shape=(150,150, 3),padding = 'same'))
model.add(layers.MaxPooling2D((2, 2),padding = 'same'))
model.add(layers.Conv2D(64, (3, 3), activation=leaky_relu,padding = 'same'))
model.add(layers.MaxPooling2D((2, 2),padding = 'same'))
model.add(layers.Conv2D(128, (3, 3), activation=leaky_relu,padding = 'same'))
model.add(layers.MaxPooling2D((2, 2),padding = 'same'))
model.add(layers.Conv2D(256, (3, 3), activation=leaky_relu,padding = 'same'))
model.add(layers.MaxPooling2D((2, 2),padding = 'same'))
model.add(layers.Flatten())                            #1차원으로 차원으로 변경 
model.add(layers.Dense(512, activation=leaky_relu))

model.add(layers.Dense(15, activation='softmax'))

# %%
model.summary()

# %%
from keras import optimizers

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.rmsprop(lr=1e-3),
              metrics=['acc'])

# %% [markdown]
# # 데이터 전처리

# %%
from keras.preprocessing.image import ImageDataGenerator

# 모든 이미지를 1/255로 스케일을 조정합니다
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # 타깃 디렉터리
        train_dir,
        # 모든 이미지를 150 × 150 크기로 바꿉니다
        target_size=(150, 150),
        batch_size=25,
        class_mode='categorical'  
        #color_mode='grayscale'
      
       )

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=25,
        class_mode='categorical'
        #color_mode='grayscale'   
)

# %%
from tensorflow.compat.v1 import ConfigProto

from tensorflow.compat.v1 import InteractiveSession



config = ConfigProto()

config.gpu_options.allow_growth = True

session = InteractiveSession(config=config)


for data_batch, labels_batch in train_generator:
    print('배치 데이터 크기:', data_batch.shape)
    print('배치 레이블 크기:', labels_batch.shape)
    break
    
history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=50,
     
      validation_data=validation_generator,
      validation_steps=60)

# %% [markdown]
# # 모델 저장

# %%
model.save('artist_small_1.h5')

# %%
import matplotlib.pyplot as plt    
###
# matplotlib이란?
# - 그래프를 그려주는 라이브러리로 쉽게 그래프 그리기와 데이터 시각화해주는 도구인데 ,
 #  matplotlib의 pyplot모듈 을 plt 라는 별명으로 붙여  모듈을 불러온다는 것

acc = history.history['acc']                    #저장된 히스토리의 정확도를 나타내는[acc]힝목을 acc에 넣어줌
val_acc = history.history['val_acc']    #저장된 히스토리의 벨리데이션의 정확도를 나타내는[val_acc]힝목을 val_acc에 
loss = history.history['loss']        # 히스토리에서 손실을 나타내는 [loss]힝목을 loss에 넣어줌
val_loss = history.history['val_loss']   # 히스토리에서 벨리데이션의 손실을 나타내는 [val_loss]힝목을 
                                                                 #val_loss에 넣어줌

epochs = range(len(acc))                    #0부터 acc의 길이의 -1 까지 수를 변수epochs 대입 
                                                    #즉 0~29까지
plt.plot(epochs, acc, 'bo', label='Training acc')          # x축을 epochs,y축을 acc 파란색 점, 제목을 Training acc으로 
plt.plot(epochs, val_acc, 'b', label='Validation acc')          #그래프를 그림
plt.title('Training and validation accuracy')              #  그래프 제목을 Training and validation accuracy
plt.legend()                                              #범례는 dfalut 값으로 

plt.figure()                           #plt.figure()를 통해 객체를 생성




plt.plot(epochs, loss, 'bo', label='Training loss')              
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # vgg16 적용해보기

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

# %% [markdown]
# # keras.applications 모듈에서 사용 가능한 이미지 분류 모델은 다음과 같습니다(모두 ImageNet 데이터셋에서 훈련되었습니다):
#
# Xception
# InceptionV3
# ResNet50
# VGG16
# VGG19
# MobileNet////////////
# weights는 모델을 초기화할 가중치 체크포인트를 지정합니다.
# include_top은 네트워크의 최상위 완전 연결 분류기를 포함할지 안할지를 지정합니다. 기본값은 ImageNet의 1,000개의 클래스에 대응되는 완전 연결 분류기를 포함합니다. 별도의 (강아지와 고양이 두 개의 클래스를 구분하는) 완전 연결 층을 추가하려고 하므로 이를 포함시키지 않습니다.
# input_shape은 네트워크에 주입할 이미지 텐서의 크기입니다. 이 매개변수는 선택사항입니다. 이 값을 지정하지 않으면 네트워크가 어떤 크기의 입력도 처리할 수 있습니다.

# %%
conv_base.summary()

# %%
import sys
mod = sys.modules[__name__]
import math
from keras import layers
from keras import models
import tensorflow as tf
import numpy as np
from keras import layers
from keras import models
import os, shutil

np.random.seed(3)

sess = tf.Session(config=tf.ConfigProto(
gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction = 0.4), log_device_placement=True))


# 원본 데이터셋을 압축 해제한 디렉터리 경로
original_dataset_dir = 'C:/Users/Affinity/Desktop/project/images/images'

# 소규모 데이터셋을 저장할 디렉터리
base_dir =  'C:/Users/Affinity/Desktop/project/classification'
if os.path.exists(base_dir):  # 반복적인 실행을 위해 디렉토리를 삭제합니다.
    shutil.rmtree(base_dir)   # 하위 디렉토리 및 파일 전체 삭제하기: rmtree()
os.mkdir(base_dir)     

# 훈련, 검증, 테스트 분할을 위한 디렉터리
train_dir = os.path.join(base_dir, 'train')  #os.path.join()  하위 경로 만들기
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# 훈련용 Vincent van Gogh  디렉터리
train_Vincent_van_Gogh_dir = os.path.join(train_dir, 'Vincent van Gogh')
os.mkdir(train_Vincent_van_Gogh_dir)

# 훈련용 Edgar Degas 디렉터리
train_Edgar_Degas_dir = os.path.join(train_dir, 'Edgar Degas')
os.mkdir(train_Edgar_Degas_dir)

# 훈련용 Pablo Picasso 디렉터리
train_Pablo_Picasso_dir = os.path.join(train_dir, 'Pablo Picasso')
os.mkdir(train_Pablo_Picasso_dir)

# 훈련용 Pierre-Auguste Renoir 디렉터리
train_Pierre_Auguste_Renoir_dir = os.path.join(train_dir, 'Pierre_Auguste Renoir')
os.mkdir(train_Pierre_Auguste_Renoir_dir)

# 훈련용 Albrecht_Du_rer 디렉터리
train_Albrecht_Du_rer_dir = os.path.join(train_dir, 'Albrecht_Du_rer')
os.mkdir(train_Albrecht_Du_rer_dir)

# 훈련용 Paul Gauguin 디렉터리
train_Paul_Gauguin_dir = os.path.join(train_dir, 'Paul Gauguin')
os.mkdir(train_Paul_Gauguin_dir)

# 훈련용 Francisco_Goya 디렉터리
train_Francisco_Goya_dir = os.path.join(train_dir, 'Francisco_Goya')
os.mkdir(train_Francisco_Goya_dir)

# 훈련용 Rembrandt 디렉터리
train_Rembrandt_dir = os.path.join(train_dir, 'Rembrandt')
os.mkdir(train_Rembrandt_dir)

# 훈련용 Alfred_Sisley 디렉터리
train_Alfred_Sisley_dir = os.path.join(train_dir, 'Alfred_Sisley')
os.mkdir(train_Alfred_Sisley_dir)

# 훈련용 Titian 디렉터리
train_Titian_dir = os.path.join(train_dir, 'Titian')
os.mkdir(train_Titian_dir)

# 훈련용 Marc_Chagall 디렉터리
train_Marc_Chagall_dir = os.path.join(train_dir, 'Marc_Chagall')
os.mkdir(train_Marc_Chagall_dir)

# 훈련용 Rene_Magritte 디렉터리
train_Rene_Magritte_dir = os.path.join(train_dir, 'Rene_Magritte')
os.mkdir(train_Rene_Magritte_dir)

# 훈련용 Amedeo_Modigliani 디렉터리
train_Amedeo_Modigliani_dir = os.path.join(train_dir, 'Amedeo_Modigliani')
os.mkdir(train_Amedeo_Modigliani_dir)

# 훈련용 Paul_Klee 디렉터리
train_Paul_Klee_dir = os.path.join(train_dir, 'Paul_Klee')
os.mkdir(train_Paul_Klee_dir)

# 훈련용 Henri_Matisse 디렉터리
train_Henri_Matisse_dir = os.path.join(train_dir, 'Henri_Matisse')
os.mkdir(train_Henri_Matisse_dir)



#-----------------------------------------------------------


# 검증용 Vincent van Gogh  디렉터리
validation_Vincent_van_Gogh_dir = os.path.join(validation_dir, 'Vincent van Gogh')
os.mkdir(validation_Vincent_van_Gogh_dir)

# 검증용 Edgar Degas 디렉터리
validation_Edgar_Degas_dir = os.path.join(validation_dir, 'Edgar Degas')
os.mkdir(validation_Edgar_Degas_dir)

# 검증용 Pablo Picasso 디렉터리
validation_Pablo_Picasso_dir = os.path.join(validation_dir, 'Pablo Picasso')
os.mkdir(validation_Pablo_Picasso_dir)

# 검증용 Pierre-Auguste Renoir 디렉터리
validation_Pierre_Auguste_Renoir_dir = os.path.join(validation_dir, 'Pierre_Auguste Renoir')
os.mkdir(validation_Pierre_Auguste_Renoir_dir)

# 검증용 Albrecht_Du_rer 디렉터리
validation_Albrecht_Du_rer_dir = os.path.join(validation_dir, 'Albrecht_Du_rer')
os.mkdir(validation_Albrecht_Du_rer_dir)

# 검증용 Paul Gauguin 디렉터리
validation_Paul_Gauguin_dir = os.path.join(validation_dir, 'Paul Gauguin')
os.mkdir(validation_Paul_Gauguin_dir)

# 검증용 Francisco_Goya 디렉터리
validation_Francisco_Goya_dir = os.path.join(validation_dir, 'Francisco_Goya')
os.mkdir(validation_Francisco_Goya_dir)

# 검증용 Rembrandt 디렉터리
validation_Rembrandt_dir = os.path.join(validation_dir, 'Rembrandt')
os.mkdir(validation_Rembrandt_dir)

# 검증용 Alfred_Sisley 디렉터리
validation_Alfred_Sisley_dir = os.path.join(validation_dir, 'Alfred_Sisley')
os.mkdir(validation_Alfred_Sisley_dir)

# 검증용 Titian 디렉터리
validation_Titian_dir = os.path.join(validation_dir, 'Titian')
os.mkdir(validation_Titian_dir)

# 검증용 Marc_Chagall 디렉터리
validation_Marc_Chagall_dir = os.path.join(validation_dir, 'Marc_Chagall')
os.mkdir(validation_Marc_Chagall_dir)

# 검증용 Rene_Magritte 디렉터리
validation_Rene_Magritte_dir = os.path.join(validation_dir, 'Rene_Magritte')
os.mkdir(validation_Rene_Magritte_dir)

# 검증용 Amedeo_Modigliani 디렉터리
validation_Amedeo_Modigliani_dir = os.path.join(validation_dir, 'Amedeo_Modigliani')
os.mkdir(validation_Amedeo_Modigliani_dir)

# 검증용 Paul_Klee 디렉터리
validation_Paul_Klee_dir = os.path.join(validation_dir, 'Paul_Klee')
os.mkdir(validation_Paul_Klee_dir)

# 검증용 Henri_Matisse 디렉터리
validation_Henri_Matisse_dir = os.path.join(validation_dir, 'Henri_Matisse')
os.mkdir(validation_Henri_Matisse_dir)
#---------------------------------------------------------------------------------------------

# 테스트용 Vincent van Gogh  디렉터리
test_Vincent_van_Gogh_dir = os.path.join(test_dir, 'Vincent van Gogh')
os.mkdir(test_Vincent_van_Gogh_dir)

# 테스트용 Edgar Degas 디렉터리
test_Edgar_Degas_dir = os.path.join(test_dir, 'Edgar Degas')
os.mkdir(test_Edgar_Degas_dir)

# 테스트용 Pablo Picasso 디렉터리
test_Pablo_Picasso_dir = os.path.join(test_dir, 'Pablo Picasso')
os.mkdir(test_Pablo_Picasso_dir)

# 테스트용 Pierre-Auguste Renoir 디렉터리
test_Pierre_Auguste_Renoir_dir = os.path.join(test_dir, 'Pierre_Auguste Renoir')
os.mkdir(test_Pierre_Auguste_Renoir_dir)

# 테스트용 Albrecht_Du_rer 디렉터리
test_Albrecht_Du_rer_dir = os.path.join(test_dir, 'Albrecht_Du_rer')
os.mkdir(test_Albrecht_Du_rer_dir)

# 테스트용 Paul Gauguin 디렉터리
test_Paul_Gauguin_dir = os.path.join(test_dir, 'Paul Gauguin')
os.mkdir(test_Paul_Gauguin_dir)

# 테스트용 Francisco_Goya 디렉터리
test_Francisco_Goya_dir = os.path.join(test_dir, 'Francisco_Goya')
os.mkdir(test_Francisco_Goya_dir)

# 테스트용 Rembrandt 디렉터리
test_Rembrandt_dir = os.path.join(test_dir, 'Rembrandt')
os.mkdir(test_Rembrandt_dir)

# 테스트용 Alfred_Sisley 디렉터리
test_Alfred_Sisley_dir = os.path.join(test_dir, 'Alfred_Sisley')
os.mkdir(test_Alfred_Sisley_dir)

# 테스트용 Titian 디렉터리
test_Titian_dir = os.path.join(test_dir, 'Titian')
os.mkdir(test_Titian_dir)

# 테스트용 Marc_Chagall 디렉터리
test_Marc_Chagall_dir = os.path.join(test_dir, 'Marc_Chagall')
os.mkdir(test_Marc_Chagall_dir)

# 테스트용 Rene_Magritte 디렉터리
test_Rene_Magritte_dir = os.path.join(test_dir, 'Rene_Magritte')
os.mkdir(test_Rene_Magritte_dir)

# 테스트용 Amedeo_Modigliani 디렉터리
test_Amedeo_Modigliani_dir = os.path.join(test_dir, 'Amedeo_Modigliani')
os.mkdir(test_Amedeo_Modigliani_dir)

# 테스트용 Paul_Klee 디렉터리
test_Paul_Klee_dir = os.path.join(test_dir, 'Paul_Klee')
os.mkdir(test_Paul_Klee_dir)

# 테스트용 Henri_Matisse 디렉터리
test_Henri_Matisse_dir = os.path.join(test_dir, 'Henri_Matisse')
os.mkdir(test_Henri_Matisse_dir)

path1= "C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh"     
count1=len(os.listdir(path1))                                
count51=math.ceil(count1*0.5)                                # 각 데이터의 50퍼센트 계산(훈련 셋)                                  
count81=math.ceil(count1*0.8)       # 각 데이터의 80퍼센트 계산(테스트 셋)

path2= "C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas"     
count2=len(os.listdir(path2))
count52=math.ceil(count2*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count82=math.ceil(count2*0.8)       # 각 데이터의 80퍼센트 계산


path3= "C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso"     
count3=len(os.listdir(path3))
count53=math.ceil(count3*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count83=math.ceil(count3*0.8)          # 각 데이터의 80퍼센트 계산


path4= "C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir"     
count4=len(os.listdir(path4))
count54=math.ceil(count4*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count84=math.ceil(count4*0.8)      # 각 데이터의 80퍼센트 계산

path5= "C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer"     
count5=len(os.listdir(path5))
count55=math.ceil(count5*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count85=math.ceil(count5*0.8)      # 각 데이터의 80퍼센트 계산

path6= "C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin"     
count6=len(os.listdir(path6))  
count56=math.ceil(count6*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count86=math.ceil(count6*0.8)       # 각 데이터의 80퍼센트 계산
   
path7= "C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya"     
count7=len(os.listdir(path7))
count57=math.ceil(count7*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count87=math.ceil(count7*0.8)        # 각 데이터의 80퍼센트 계산

path8= "C:/Users/Affinity/Desktop/project/images/images/Rembrandt"     
count8=len(os.listdir(path8))
count58=math.ceil(count8*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count88=math.ceil(count8*0.8)      # 각 데이터의 80퍼센트 계산


path9= "C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley"     
count9=len(os.listdir(path9))
count59=math.ceil(count9*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count89=math.ceil(count9*0.8)      # 각 데이터의 80퍼센트 계산


path10= "C:/Users/Affinity/Desktop/project/images/images/Titian"     
count10=len(os.listdir(path10))
count10_5=math.ceil(count10*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count10_8=math.ceil(count10*0.8)     # 각 데이터의 80퍼센트 계산


path11= "C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall"     
count11=len(os.listdir(path11))
count11_5=math.ceil(count11*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count11_8=math.ceil(count11*0.8)       # 각 데이터의 80퍼센트 계산


path12= "C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte"     
count12=len(os.listdir(path12))
count12_5=math.ceil(count12*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count12_8=math.ceil(count12*0.8)       # 각 데이터의 80퍼센트 계산


path13= "C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani"     
count13=len(os.listdir(path13))
count13_5=math.ceil(count13*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count13_8=math.ceil(count13*0.8)           # 각 데이터의 80퍼센트 계산

path14= "C:/Users/Affinity/Desktop/project/images/images/Paul_Klee"     
count14=len(os.listdir(path14))
count14_5=math.ceil(count14*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count14_8=math.ceil(count14*0.8)       # 각 데이터의 80퍼센트 계산

path15= "C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse"     
count15=len(os.listdir(path15))
count15_5=math.ceil(count15*0.5)                                # 각 데이터의 50퍼센트 계산                                  
count15_8=math.ceil(count15*0.8)        # 각 데이터의 80퍼센트 계산



#----------------------------------------------------------------------
#처음 n 개의 train_Vincent_van_Gogh그림을 train_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(1,count51)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(train_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)

# 다음 n개 train_Vincent_van_Gogh 그림을 validation_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(count51, count81)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(validation_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)
    
# 다음 n개 train_Vincent_van_Gogh 그림을 test_Vincent_van_Gogh_dir에 복사합니다
fnames = ['Vincent_van_Gogh_{}.jpg'.format(i) for i in range(count81, count1)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Vincent_van_Gogh", fname)
    dst = os.path.join(test_Vincent_van_Gogh_dir, fname)
    shutil.copyfile(src, dst)
 
    
#처음 n 개의 Edgar_Degas그림을 train_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(1,count52)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(train_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)

# 다음 n개 Edgar_Degas 그림을 validation_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(count52, count82)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(validation_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)
    
# 다음 n개 Edgar_Degas그림을 test_Edgar_Degas_dir에 복사합니다
fnames = ['Edgar_Degas_{}.jpg'.format(i) for i in range(count82, count2)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Edgar_Degas", fname)
    dst = os.path.join(test_Edgar_Degas_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(1,count53)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(train_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(count53, count83)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(validation_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Pablo_Picasso_{}.jpg'.format(i) for i in range(count83, count3)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pablo_Picasso", fname)
    dst = os.path.join(test_Pablo_Picasso_dir, fname)
    shutil.copyfile(src, dst)
#-----    
fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(1,count54)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(train_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)


fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(count54, count84)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(validation_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)
    

fnames = ['Pierre-Auguste_Renoir_{}.jpg'.format(i) for i in range(count84, count4)]
for fname in fnames:
    src1 = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Pierre_Auguste_Renoir", fname)
    dst1 = os.path.join(test_Pierre_Auguste_Renoir_dir, fname)
    shutil.copyfile(src1, dst1)
    
#------
fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(1,count55)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(train_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(count55, count85)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(validation_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Albrecht_Du_rer_{}.jpg'.format(i) for i in range(count85, count5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Albrecht_Du_rer", fname)
    dst = os.path.join(test_Albrecht_Du_rer_dir, fname)
    shutil.copyfile(src, dst)
    
#---------    
fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(1,count56)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(train_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(count56, count86)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(validation_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Paul_Gauguin_{}.jpg'.format(i) for i in range(count86, count6)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Gauguin", fname)
    dst = os.path.join(test_Paul_Gauguin_dir, fname)
    shutil.copyfile(src, dst)
#-------    
fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(1,count57)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(train_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(count57, count87)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(validation_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Francisco_Goya_{}.jpg'.format(i) for i in range(count87, count7)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Francisco_Goya", fname)
    dst = os.path.join(test_Francisco_Goya_dir, fname)
    shutil.copyfile(src, dst)
    
    
#----------------    
fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(1,count58)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(train_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(count58, count88)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(validation_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Rembrandt_{}.jpg'.format(i) for i in range(count88, count8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rembrandt", fname)
    dst = os.path.join(test_Rembrandt_dir, fname)
    shutil.copyfile(src, dst)
    
#-------------
fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(1,count59)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(train_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(count59, count89)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(validation_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Alfred_Sisley_{}.jpg'.format(i) for i in range(count89, count9)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Alfred_Sisley", fname)
    dst = os.path.join(test_Alfred_Sisley_dir, fname)
    shutil.copyfile(src, dst)
    
#---------------------

fnames = ['Titian_{}.jpg'.format(i) for i in range(1,count10_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(train_Titian_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Titian_{}.jpg'.format(i) for i in range(count10_5, count10_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(validation_Titian_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Titian_{}.jpg'.format(i) for i in range(count10_8, count10)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Titian", fname)
    dst = os.path.join(test_Titian_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(1,count11_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(train_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(count11_5, count11_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(validation_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Marc_Chagall_{}.jpg'.format(i) for i in range(count11_8, count11)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Marc_Chagall", fname)
    dst = os.path.join(test_Marc_Chagall_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(1,count12_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(train_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(count12_5, count12_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(validation_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Rene_Magritte_{}.jpg'.format(i) for i in range(count12_8, count12)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Rene_Magritte", fname)
    dst = os.path.join(test_Rene_Magritte_dir, fname)
    shutil.copyfile(src, dst)
    
    
#------------
fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(1,count13_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(train_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(count13_5, count13_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(validation_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Amedeo_Modigliani_{}.jpg'.format(i) for i in range(count13_8, count13)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Amedeo_Modigliani", fname)
    dst = os.path.join(test_Amedeo_Modigliani_dir, fname)
    shutil.copyfile(src, dst)
    
#------------
fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(1,count14_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(train_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(count14_5, count14_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(validation_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Paul_Klee_{}.jpg'.format(i) for i in range(count14_8, count14)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Paul_Klee", fname)
    dst = os.path.join(test_Paul_Klee_dir, fname)
    shutil.copyfile(src, dst)

#------------
fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(1,count15_5)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(train_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)


fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(count15_5, count15_8)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(validation_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)
    

fnames = ['Henri_Matisse_{}.jpg'.format(i) for i in range(count15_8, count15)]
for fname in fnames:
    src = os.path.join("C:/Users/Affinity/Desktop/project/images/images/Henri_Matisse", fname)
    dst = os.path.join(test_Henri_Matisse_dir, fname)
    shutil.copyfile(src, dst)


    # for i in range(10,16):
#     setattr(mod, 'test{}'.format(i), i)
#     print(getattr(mod, 'count{}_5'.format(i)))
#     print(src)

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

base_dir =  'C:/Users/Affinity/Desktop/project/classification'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

datagen = ImageDataGenerator(rescale=1./255)
batch_size = 20

def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, 4, 4, 512))
    labels = np.zeros(shape=(sample_count, 15))
    generator = datagen.flow_from_directory(
        directory,
        target_size=(150, 150),
        batch_size=batch_size,
        #color_mode='grayscale',
        class_mode='categorical')
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            # 제너레이터는 루프 안에서 무한하게 데이터를 만들어내므로 모든 이미지를 한 번씩 처리하고 나면 중지합니다
            break
    return features, labels

train_features, train_labels = extract_features(train_dir,2500)
validation_features, validation_labels = extract_features(validation_dir, 1500)
test_features, test_labels = extract_features(test_dir, 1000)

# %%
train_features = np.reshape(train_features, (2500, 4 * 4 * 512))
validation_features = np.reshape(validation_features, (1500, 4 * 4 * 512))
test_features = np.reshape(test_features, (1000, 4 * 4 * 512))

# %%
from keras import models
from keras import layers
from keras import optimizers

model=models.Sequential()
model.add(layers.Dense(256, activation='relu', input_dim=4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(15, activation='softmax'))

model.compile(optimizer=optimizers.RMSprop(lr=2e-5),
              loss='categorical_crossentropy',
              metrics=['acc'])

history = model.fit(train_features, train_labels,
                    epochs=30,
                    batch_size=20,
                    validation_data=(validation_features, validation_labels))

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(15, activation='softmax'))

# %%
model.summary()

# %%
#vgg16 기본층 동결
conv_base.trainable = False

# %% [markdown]
# 이렇게 설정하면 추가한 두 개의 Dense 층의 가중치만 훈련될 것입니다. 층마다 두 개씩(가중치 행렬과 편향 벡터) 총 네 개의 텐서가 훈련됩니다. 변경 사항을 적용하려면 먼저 모델을 컴파일해야 합니다. 컴파일 단계 후에 trainable 속성을 변경하면 반드시 모델을 다시 컴파일해야 합니다. 그렇지 않으면 변경 사항이 적용되지 않습니다.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.1,
      horizontal_flip=True,
      fill_mode='nearest')

# 검증 데이터는 증식되어서는 안 됩니다!
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # 타깃 디렉터리
        train_dir,
        # 모든 이미지의 크기를 150 × 150로 변경합니다
        target_size=(150, 150),
        batch_size=20,
        # binary_crossentropy 손실을 사용하므로 이진 레이블이 필요합니다
        )

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        )

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=2e-5),
              metrics=['acc'])

history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=50,
      verbose=2)

# %%
model.save('artist.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
conv_base.summary()

# %%
conv_base.trainable = True

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-5),
              metrics=['acc'])

history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=50)

# %%
model.save('artist_4.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=20,
        )

test_loss, test_acc = model.evaluate_generator(test_generator, steps=50)
print('test acc:', test_acc)

# %% [markdown]
# #  중간 층의 활성화 시각화하기

# %%
from keras.models import load_model

model = load_model('cats_and_dogs_small_1.h5')
model.summary()  # 기억을 되살리기 위해서 모델 구조를 출력합니다

# %%
img_path = 'C:/Users/Affinity/Desktop/project/classification/test/Alfred_Sisley/Alfred_Sisley_208.jpg'

# 이미지를 4D 텐서로 변경합니다
from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(150, 150))
img_tensor = image.img_to_array(img)                          #이미지를 배열로
img_tensor = np.expand_dims(img_tensor, axis=0)                      #이미지를 4D 텐서로 변경
# 모델이 훈련될 때 입력에 적용한 전처리 방식을 동일하게 사용합니다
img_tensor /= 255.

# 이미지 텐서의 크기는 (1, 150, 150, 3)입니다
print(img_tensor.shape)

# %%
import matplotlib.pyplot as plt
plt.imshow(img_tensor[0])
plt.show()

# %%
from keras import models

# 상위 8개 층의 출력을 추출합니다:
layer_outputs = [layer.output for layer in model.layers[:8]]
# 입력에 대해 8개 층의 출력을 반환하는 모델을 만듭니다:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# 층의 활성화마다 하나씩 8개의 넘파이 배열로 이루어진 리스트를 반환합니다:
activations = activation_model.predict(img_tensor)

first_layer_activation = activations[0]
print(first_layer_activation.shape)

plt.matshow(first_layer_activation[0, :, :, 19], cmap='viridis')
plt.show()
# first_layer_activation = activations[0]
# print(first_layer_activation.shape)

# %%
plt.matshow(first_layer_activation[0, :, :, 15], cmap='viridis')
plt.show()

# %%
# 층의 이름을 그래프 제목으로 사용합니다
layer_names = []
for layer in model.layers[:8]:
    layer_names.append(layer.name)  

images_per_row = 16

# 특성 맵을 그립니다
for layer_name, layer_activation in zip(layer_names, activations):
    # 특성 맵에 있는 특성의 수
    n_features = layer_activation.shape[-1]

    # 특성 맵의 크기는 (1, size, size, n_features)입니다
    size = layer_activation.shape[1]

    # 활성화 채널을 위한 그리드 크기를 구합니다
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # 각 활성화를 하나의 큰 그리드에 채웁니다
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # 그래프로 나타내기 좋게 특성을 처리합니다
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # 그리드를 출력합니다
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')

plt.show()

# %% [markdown]
# #  컨브넷 필터 시각화

# %%
from keras.applications import VGG16
from keras import backend as K

model = VGG16(weights='imagenet',
              include_top=False)

layer_name = 'block3_conv1'
filter_index = 0

layer_output = model.get_layer(layer_name).output
loss = K.mean(layer_output[:, :, :, filter_index])

# gradients 함수가 반환하는 텐서 리스트(여기에서는 크기가 1인 리스트)에서 첫 번째 텐서를 추출합니다
grads = K.gradients(loss, model.input)[0]

# %% [markdown]
# 경사 상승법을 구현하기 위해 모델의 입력에 대한 손실의 그래디언트가 필요합니다. 이를 위해 케라스의 backend 모듈에 있는 gradients 함수를 사용
#
# 경사 상승법 과정을 부드럽게 하기 위해 사용하는 한 가지 기법은 그래디언트 텐서를 L2 노름(텐서에 있는 값을 제곱합의 제곱근)으로 나누어 정규화하는 것입니다. 이렇게 하면 입력 이미지에 적용할 수정량의 크기를 항상 일정 범위 안에 놓을 수 있습니다.

# %%
# 0 나눗셈을 방지하기 위해 1e–5을 더합니다
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# %% [markdown]
# #
# 이제 주어진 입력 이미지에 대해 손실 텐서와 그래디언트 텐서를 계산해야 합니다. 케라스 백엔드 함수를 사용하여 처리하겠습니다. iterate는 넘파이 텐서(크기가 1인 텐서의 리스트)를 입력으로 받아 손실과 그래디언트 두 개의 넘파이 텐서를 반환합니다.

# %%
iterate = K.function([model.input], [loss, grads])

# 테스트:
import numpy as np
loss_value, grads_value = iterate([np.zeros((1, 150, 150, 3))])

# %% [markdown]
# #  여기에서 파이썬 루프를 만들어 확률적 경사 상승법을 구성합니다

# %%
# 잡음이 섞인 회색 이미지로 시작합니다
input_img_data = np.random.random((1, 150, 150, 3)) * 20 + 128.

# 업데이트할 그래디언트의 크기
step = 1.
for i in range(40):   # 경사 상승법을 40회 실행합니다
    # 손실과 그래디언트를 계산합니다
    loss_value, grads_value = iterate([input_img_data])
    # 손실을 최대화하는 방향으로 입력 이미지를 수정합니다
    input_img_data += grads_value * step

# %% [markdown]
# 결과 이미지 텐서는 (1, 150, 150, 3) 크기의 부동 소수 텐서입니다. 이 텐서의 값은 [0, 255] 사이의 정수가 아닙니다. 따라서 출력 가능한 이미지로 변경하기 위해 후처리할 필요가 있습니다. 이를 위해 간단한 함수를 정의해 사용

# %%
def deprocess_image(x):
    # 텐서의 평균이 0, 표준 편차가 0.1이 되도록 정규화합니다
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # [0, 1]로 클리핑합니다
    x += 0.5
    x = np.clip(x, 0, 1)

    # RGB 배열로 변환합니다
    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# #  이 코드를 모아서 층의 이름과 필터 번호를 입력으로 받는 함수를 만들겠습니다. 이 함수는 필터 활성화를 최대화하는 패턴을 이미지 텐서로 출력

# %%
def generate_pattern(layer_name, filter_index, size=150):
    # 주어진 층과 필터의 활성화를 최대화하기 위한 손실 함수를 정의합니다
    layer_output = model.get_layer(layer_name).output
    loss = K.mean(layer_output[:, :, :, filter_index])

    # 손실에 대한 입력 이미지의 그래디언트를 계산합니다
    grads = K.gradients(loss, model.input)[0]

    # 그래디언트 정규화
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # 입력 이미지에 대한 손실과 그래디언트를 반환합니다
    iterate = K.function([model.input], [loss, grads])
    
    # 잡음이 섞인 회색 이미지로 시작합니다
    input_img_data = np.random.random((1, size, size, 3)) * 20 + 128.

    # 경사 상승법을 40 단계 실행합니다
    step = 1.
    for i in range(40):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step
        
    img = input_img_data[0]
    return deprocess_image(img)

# %%
plt.imshow(generate_pattern('block3_conv1', 0))
plt.show()

# %%
for layer_name in ['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1']:
    size = 64
    margin = 5

    # 결과를 담을 빈 (검은) 이미지
    results = np.zeros((8 * size + 7 * margin, 8 * size + 7 * margin, 3), dtype='uint8')

    for i in range(8):  # results 그리드의 행을 반복합니다
        for j in range(8):  # results 그리드의 열을 반복합니다
            # layer_name에 있는 i + (j * 8)번째 필터에 대한 패턴 생성합니다
            filter_img = generate_pattern(layer_name, i + (j * 8), size=size)

            # results 그리드의 (i, j) 번째 위치에 저장합니다
            horizontal_start = i * size + i * margin
            horizontal_end = horizontal_start + size
            vertical_start = j * size + j * margin
            vertical_end = vertical_start + size
            results[horizontal_start: horizontal_end, vertical_start: vertical_end, :] = filter_img

    # results 그리드를 그립니다
    plt.figure(figsize=(20, 20))
    plt.imshow(results)
    plt.show()

# %%
print(acc.shape)
